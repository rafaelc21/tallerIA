# %% [markdown]
# # Usando Document Loader

# %% [markdown]
#  🔍 **¿Qué es Document Loader?**
# Un Document Loader es un componente de LangChain cuya misión principal es:
# Cargar datos desde distintas fuentes y convertirlos en objetos **Document**, para que la IA pueda trabajar con ellos.
# Proporcionan métodos para cargar datos como:
# ✅ PDFs
# ✅ Archivos Word (.docx)
# ✅ Archivos de texto (.txt)
# ✅ Excel (.xlsx)
# ✅ Páginas web (URL)
# ✅ Bases de datos (SQL)
# ✅ Carpetas enteras
# ✅ Otras de aplicaciones como Notion, Evernote, etc.

# %% [markdown]
# ![Imagen](https://miro.medium.com/v2/resize:fit:828/format:webp/1*ZwDfKQkV6RUhp35aJjW0Iw.png)

# %% [markdown]
# ## 📦 ¿Qué es un Document?
# Un Document es una estructura de datos estándar en LangChain que representa un fragmento de información textual con sus metadatos.
# La estructura de datos contiene:
# **📄 page_content:** el texto del documento.
# **🏷️ metadata:** un diccionario con metadatos relacionados al contenido (como la fuente, posición, timestamp, etc.).

# %%
from langchain.schema import Document

doc = Document(
    page_content="L7" \
    "" \
    "a inteligencia artificial está transformando el mundo.",
    metadata={
        "source": "articulo_web",
        "url": "https://example.com/ia",
        "author": "Juan Pérez",
        "fecha": "2024-12-01",
        "page": 2
    }
)

# %%
print(doc.page_content)
# ➤ "La inteligencia artificial está transformando el mundo."

print(doc.metadata)
# ➤ {
#      "source": "articulo_web",
#      "url": "https://example.com/ia",
#      "author": "Juan Pérez",
#      "fecha": "2024-12-01",
#      "page": 2
#    }
# Out:
# L7a inteligencia artificial está transformando el mundo.
# {'source': 'articulo_web', 'url': 'https://example.com/ia', 'author': 'Juan Pérez', 'fecha': '2024-12-01', 'page': 2}

# %% [markdown]
# #### 🧠 **¿Para qué se usa la metadata?**
# Para saber de dónde vino el contenido.
# Para filtrar los resultados por fuente o tipo.
# Para hacer trazabilidad del conocimiento.
# Para indicar tiempo (start, end) si viene de audio o video.
# Para paginar textos largos.

# %% [markdown]
# ## Web

# %%
# 👉 Document Loader especializado en leer el contenido HTML de una URL, extraer el texto legible, y lo transforma en un documento que LangChain.
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://www.unesco.org/es/digital-education/artificial-intelligence") #WebBaseLoader(["https://url1/", "https://url2"])
dataweb = loader.load()

# %%
len(dataweb), dataweb
# Out:
# (1,
# ...

# %% [markdown]
# ## PDF

# %%
pwd
# Out:
# '/workspaces/tallerIA'

# %%
# 👉 Document Loader especializado en leer archivos PDF, extraer el texto legible, y lo transforma en un documento que LangChain.
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("3.2_data/StateofAI-Espanol.pdf")
datapdf = loader.load()

# %%
len(datapdf), datapdf
# Out:
# (79,
#  [Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2023-06-28T10:39:53-06:00', 'title': 'PowerPoint Presentation', 'author': 'MBA - Rick Prieto', 'moddate': '2023-06-28T10:39:53-06:00', 'source': '3.2_data/StateofAI-Espanol.pdf', 'total_pages': 79, 'page': 0, 'page_label': '1'}, page_content='Estado de la IA.\nAmérica Latina 2023\nReporte de investigación de ALLVP'),
# ...

# %% [markdown]
# # CSV

# %%
# 👉 Document Loader especializado en leer archivos CSV y Convierte cada fila del CSV en un objeto Document de LangChain.
from langchain.document_loaders.csv_loader import CSVLoader

loader = CSVLoader( file_path = "3.2_data/minerasdelmundo.csv",
                    #source_column="TipoMina",  # 👉 Esta columna será el contenido principal
                    metadata_columns=["Pais"],  # 👉 Esta columna se incluirá como metadato
                    encoding="utf-8",  # 👈 importante para caracteres especiales
                    csv_args={"delimiter": ","}
                  )
datacsv = loader.load()

# %%
len(datacsv), datacsv
# Out:
# (56,
#  [Document(metadata={'source': '3.2_data/minerasdelmundo.csv', 'row': 0, 'Pais': 'Chile'}, page_content='N: 1\nMina: Escondida\nEmpresa: BHP\nAnioOperacion: 1990\nTipoMina: Open pit\nMetal: Cobre'),
#   Document(metadata={'source': '3.2_data/minerasdelmundo.csv', 'row': 1, 'Pais': 'Chile'}, page_content='N: 2\nMina: Chuquicamata\nEmpresa: Codelco\nAnioOperacion: 1915\nTipoMina: Open pit\nMetal: Cobre'),
#   Document(metadata={'source': '3.2_data/minerasdelmundo.csv', 'row': 2, 'Pais': 'Chile'}, page_content='N: 3\nMina: Collahuasi\nEmpresa: Anglo American\nAnioOperacion: 1993\nTipoMina: Open pit\nMetal: Cobre'),
#   Document(metadata={'source': '3.2_data/minerasdelmundo.csv', 'row': 3, 'Pais': 'Polonia'}, page_content='N: 4\nMina: Radom\nEmpresa: KGHM Polska Mied?\nAnioOperacion: 1957\nTipoMina: Underground\nMetal: Cobre'),
# ...

# %% [markdown]
# ## 🧠 ¿Qué es un DocumentTransformer?

# %% [markdown]
# Es una clase que toma uno o varios documentos (Document) como entrada y devuelve documentos transformados.
# Por ejemplo:
# 📎 Dividir un documento en fragmentos más pequeños.
# 📌 Agregar metadatos (como fecha, autor, etc.).
# ✂️ Filtrar partes irrelevantes.
# 🧱 Aplicar embeddings o anotaciones.
#
#
# Un ejemplo simple es dividir un documento largo en partes más pequeñas que puedan entrar en la ventana de contexto
# de un modelo de lenguaje (GPT4, Llama 3, Mistral, Claude, DeepSeek, etc).
# (https://python.langchain.com/docs/modules/data_connection/document_transformers/)

# %% [markdown]
# ![image](https://miro.medium.com/v2/resize:fit:828/format:webp/1*n4XS0XkKM8RsRwgJxWpNpQ.jpeg)

# %%
len(datapdf), datapdf
# Out:
# (79,
#  [Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2023-06-28T10:39:53-06:00', 'title': 'PowerPoint Presentation', 'author': 'MBA - Rick Prieto', 'moddate': '2023-06-28T10:39:53-06:00', 'source': '3.2_data/StateofAI-Espanol.pdf', 'total_pages': 79, 'page': 0, 'page_label': '1'}, page_content='Estado de la IA.\nAmérica Latina 2023\nReporte de investigación de ALLVP'),
# ...

# %%
id=2
print(datapdf[id].page_content)
print(len(datapdf[id].page_content))
# Out:
# 04 Capital de riesgo: Integrando IA en el proceso de inversión
# 03 Corporativos: explorando el potencial de la IA
# 02 Startups: liderando el avance
# 01 Introducción a la IA: explorando la revolución
# Agenda
# 3
# 205

# %% [markdown]
# ### 🧠 ¿Qué es RecursiveCharacterTextSplitter?
# Es un algoritmo de segmentación de texto que corta el contenido en trozos ("chunks") manteniendo el mayor contexto posible,
# usando una jerarquía de separadores.
# Es muy usado cuando trabajas con:
# - Transcripciones largas de audio (como las de Whisper)
# - Documentos PDF extensos
# - Archivos CSV con mucho contenido por fila
# - Web scraping (textos largos de páginas web)

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
text = """
111111111 222222222 333333333 444444444 555555555 666666666 777777777 888888888 999999999 
"""
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 30, chunk_overlap=10)
text_splitter.create_documents([text])
# Out:
# [Document(metadata={}, page_content='111111111 222222222 333333333'),
#  Document(metadata={}, page_content='333333333 444444444 555555555'),
#  Document(metadata={}, page_content='555555555 666666666 777777777'),
#  Document(metadata={}, page_content='777777777 888888888 999999999'),
#  Document(metadata={}, page_content='999999999')]

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 500,
    chunk_overlap  = 150
)

docs = text_splitter.split_documents(datapdf)

# %%
len(datapdf)
# Out:
# 79

# %%
len(docs)
# Out:
# 149

# %%
len(docs), docs
# Out:
# (149,
#  [Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2023-06-28T10:39:53-06:00', 'title': 'PowerPoint Presentation', 'author': 'MBA - Rick Prieto', 'moddate': '2023-06-28T10:39:53-06:00', 'source': '3.2_data/StateofAI-Espanol.pdf', 'total_pages': 79, 'page': 0, 'page_label': '1'}, page_content='Estado de la IA.\nAmérica Latina 2023\nReporte de investigación de ALLVP'),
# ...

# %%
len(datapdf), datapdf
# Out:
# (79,
#  [Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2023-06-28T10:39:53-06:00', 'title': 'PowerPoint Presentation', 'author': 'MBA - Rick Prieto', 'moddate': '2023-06-28T10:39:53-06:00', 'source': '3.2_data/StateofAI-Espanol.pdf', 'total_pages': 79, 'page': 0, 'page_label': '1'}, page_content='Estado de la IA.\nAmérica Latina 2023\nReporte de investigación de ALLVP'),
# ...
